# %% [markdown]
# **Question 1**
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and
# materials.

# %%
#step1  Import the necessary libraries.
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
#step 3 assign it to a variable user
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',sep='|',index_col='user_id')

# %%
users.head(5)
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
# Step 4. Discover what is the mean age per occupation
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
#Step 6 Discover the Male ratio per occupation and sort it from the most to the least
users['male']=users['gender']=='M'
ratio = users.groupby('occupation').male.sum()/users.groupby('occupation').gender.count()
ratio.sort_values(ascending=False)
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# dtype: float64

# %%
# Step 6. For each occupation, calculate the minimum and maximum ages..
min_value = users.groupby('occupation').age.min()
max_value = users.groupby('occupation').age.max()
print(min_value)
print(max_value)
# Out:
# occupation
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# Name: age, dtype: int64
# occupation
# administrator    70
# artist           48
# doctor           64
# educator         63
# engineer         70
# entertainment    50
# executive        69
# healthcare       62
# homemaker        50
# lawyer           53
# librarian        69
# marketing        55
# none             55
# other            64
# programmer       63
# retired          73
# salesman         66
# scientist        55
# student          42
# technician       55
# writer           60
# ...

# %%
# Step 7. For each combination of occupation and sex, calculate the mean age 
mean_age = users.groupby(['occupation','gender']).age.mean()
print(mean_age)
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
# Step 8. For each occupation present the percentage of women and men
perc = users.groupby('occupation')['gender'].value_counts(normalize=True)*100
new_df = pd.DataFrame(perc)
new_df.rename(columns={'gender':'percent'},inplace = True)
new_df.reset_index(level=['occupation','gender'])
# Out:
#        occupation gender     percent
# 0   administrator      M   54.430380
# 1   administrator      F   45.569620
# 2          artist      M   53.571429
# 3          artist      F   46.428571
# 4          doctor      M  100.000000
# 5        educator      M   72.631579
# 6        educator      F   27.368421
# 7        engineer      M   97.014925
# 8        engineer      F    2.985075
# 9   entertainment      M   88.888889
# 10  entertainment      F   11.111111
# 11      executive      M   90.625000
# 12      executive      F    9.375000
# 13     healthcare      F   68.750000
# 14     healthcare      M   31.250000
# 15      homemaker      F   85.714286
# 16      homemaker      M   14.285714
# 17         lawyer      M   83.333333
# 18         lawyer      F   16.666667
# 19      librarian      F   56.862745
# 20      librarian      M   43.137255
# 21      marketing      M   61.538462
# 22      marketing      F   38.461538
# 23           none      M   55.555556
# ...

# %% [markdown]
# **Question 2**
# Euro Teams

# %%
#step 1 import the necessary library
import pandas as pd
import numpy as np

# %%
#step 2 import the dataset from https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv
# step 3 store it in euro12
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

# %%
euro12.head(10)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
# 8     Netherlands      2               12                36             25.0%
# 9          Poland      2               15                23             39.4%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# ...

# %%
#step 4 select only Goal column
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#step 5 how many teams participated in euro2012
euro12['Team'].nunique()
# Out:
# 16

# %%
# Step 6. What is the number of columns in the dataset? 
euro12.shape[1]
# Out:
# 35

# %%
# step 7 View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
discipline = pd.DataFrame(euro12[['Team','Yellow Cards','Red Cards']])
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# step 8 Sort the teams by Red Cards, then to Yellow Cards
discipline.sort_values(by=['Red Cards','Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %%
# step 9 Calculate the mean Yellow Cards given per Team
discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
# step 10 Step 10. Filter teams that scored more than 6 goals
euro12[euro12['Goals']>6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#step 11 teams that start with G
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
# step 12 select first 7 columns
euro12.iloc[:,0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# step 13 select all columns except last 3
euro12.iloc[:,0:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step 14 Present only the Shooting Accuracy from England, Italy and Russia
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# **Question 3**
# **Housing**

# %%
#step1 import the necess. libraries
import pandas as pd
import numpy as np

# %%
#Step 2. Create 3 differents Series, each of length 100, as follows:
# The first a random number from 1 to 4
series1 = pd.Series(np.random.randint(1,high=5,size=100))
# The second a random number from 1 to 3
series2 = pd.Series(np.random.randint(1,high=4,size=100))
# The third a random number from 10,000 to 30,000
series3 = pd.Series(np.random.randint(10000,high=30001,size=100))
print(series1)
print(series2)
print(series3)
# Out:
# 0     2
# 1     4
# 2     3
# 3     1
# 4     4
#      ..
# 95    2
# 96    4
# 97    4
# 98    2
# 99    2
# Length: 100, dtype: int32
# 0     3
# 1     2
# 2     1
# 3     3
# 4     1
#      ..
# 95    3
# 96    1
# 97    2
# 98    1
# 99    3
# Length: 100, dtype: int32
# 0     29706
# 1     23989
# 2     22114
# 3     12183
# 4     17597
#       ...
# 95    19939
# 96    18012
# 97    10522
# 98    13028
# 99    14566
# Length: 100, dtype: int32

# %%
# Step 3. Create a DataFrame by joinning the Series by column
df = pd.concat([series1,series2,series3],axis=1)
df
# Out:
#     0  1      2
# 0   2  3  29706
# 1   4  2  23989
# 2   3  1  22114
# 3   1  3  12183
# 4   4  1  17597
# .. .. ..    ...
# 95  2  3  19939
# 96  4  1  18012
# 97  4  2  10522
# 98  2  1  13028
# 99  2  3  14566
#
# [100 rows x 3 columns]

# %%
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
df.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       2       3            29706
# 1       4       2            23989
# 2       3       1            22114
# 3       1       3            12183
# 4       4       1            17597
# ..    ...     ...              ...
# 95      2       3            19939
# 96      4       1            18012
# 97      4       2            10522
# 98      2       1            13028
# 99      2       3            14566
#
# [100 rows x 3 columns]

# %%
# Step 5  Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.concat([series1,series2,series3],axis=0)
bigcolumn.to_frame()
# Out:
#         0
# 0       2
# 1       4
# 2       3
# 3       1
# 4       4
# ..    ...
# 95  19939
# 96  18012
# 97  10522
# 98  13028
# 99  14566
#
# [300 rows x 1 columns]

# %%
# Step 6. Ops it seems it is going only until index 99. Is it true? 
len(bigcolumn)
# Out:
# 300

# %%
# no its length is 300 or it is going until 299

# %%
# Step 7. Reindex the DataFrame so it goes from 0 to 299
bigcolumn.reset_index(drop=True, inplace=True)
bigcolumn
# Out:
# 0          2
# 1          4
# 2          3
# 3          1
# 4          4
#        ...
# 295    19939
# 296    18012
# 297    10522
# 298    13028
# 299    14566
# Length: 300, dtype: int32

# %% [markdown]
# **Question 4**
# **Wind Statistics**

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np
import datetime

# %%
#step 2 Import the dataset from the attached file wind.txt
#Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
data =  pd.read_csv("wind.txt",sep='\s+',parse_dates=[[0,1,2]])

# %%
data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
#Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
def fix_year(x):
  year = x.year - 100 if x.year > 1989 else x.year
  return datetime.date(year, x.month, x.day)

data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(fix_year)

data.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
# Step 5. Set the right dates as the index. Pay attention at the data type it should be datetime64[ns]..
data["Yr_Mo_Dy"] = pd.to_datetime(data["Yr_Mo_Dy"])
data = data.set_index('Yr_Mo_Dy')
data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %%
# Step 6. Compute how many values are missing for each location over the entire record.
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
# Step 7 Compute how many non-missing values there are in total..
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
#Step 8 Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
data.sum().sum()/data.notna().sum().sum()
# Out:
# 10.227883764282181

# %%
#Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
loc_stats = pd.DataFrame(data.describe(percentiles=[]))
loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# 50%       6.830000     9.210000     8.080000     8.170000     8.290000
# ...

# %%
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day
day_stats = pd.DataFrame()
day_stats['min'] = data.min(axis = 1) 
day_stats['max'] = data.max(axis = 1) 
day_stats['mean'] = data.mean(axis = 1) 
day_stats['std'] = data.std(axis = 1) 

day_stats.head()
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %%
# Step 11. Find the average windspeed in January for each location
data.loc[data.index.month == 1].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
# Step 12. Downsample the record to a yearly frequency for each location..
data.groupby(data.index.to_period('A')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961      12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962      12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963      12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964      12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965      12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966      13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967      12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968      11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969      11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970      12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971      11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# 1972      12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# ...

# %%
# Step 13. Downsample the record to a monthly frequency for each location.
data.groupby(data.index.to_period('M')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01   14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02   16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03   10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...             ...        ...        ...       ...        ...        ...
# 1978-08    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09   10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10    9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11   16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12   16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
# Step 14. Downsample the record to a weekly frequency for each location
data.groupby(data.index.to_period('W')).mean()
# Out:
#                              RPT        VAL        ROS        KIL        SHA  \
# Yr_Mo_Dy
# 1960-12-26/1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN
# 1961-01-02/1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286
# 1961-01-09/1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429
# 1961-01-16/1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667
# 1961-01-23/1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857
# ...                          ...        ...        ...        ...        ...
# 1978-11-27/1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714
# 1978-12-04/1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143
# 1978-12-11/1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143
# 1978-12-18/1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714
# 1978-12-25/1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000
#
# ...

# %%
#Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds
#across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

Weekly = data.resample('W').agg(['min','max','mean','std'])
Weekly.loc[Weekly.index[1:53], "RPT":"MAL"] .head(10)
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Yr_Mo_Dy
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
#
#                         ROS         ...        CLO              BEL         \
# ...

# %% [markdown]
# **Question 5**

# %%
#step 1 install the necessary libraries
import pandas as pd

# %%
#step 2 import the dataset from address.
# step 3 assign it to a variable chipo.
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %%
#step 4 see the first 10 entries
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Step 5. What is the number of observations in the dataset?
chipo.shape[0]
# Out:
# 4622

# %%
# step6 nb. of columns
chipo.shape[1]
# Out:
# 5

# %%
# step 7 print all the columns
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# step 8 How is the dataset indexed?
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# step 9 which is most ordered item?
chipo.groupby(['item_name']).quantity.sum().sort_values(ascending = False).index[0]
# Out:
# 'Chicken Bowl'

# %%
# Step 10. For the most-ordered item, how many items were ordered?
chipo.groupby('item_name').sum().sort_values(['quantity'], ascending=False).head(1)
# Out:
# C:\Users\samar\AppData\Local\Temp\ipykernel_8252\3130832145.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   chipo.groupby('item_name').sum().sort_values(['quantity'], ascending=False).head(1)
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
#Step 11. What was the most ordered item in the choice_description column? 
chipo.groupby(['choice_description']).quantity.sum().sort_values(ascending = False).index[0]
# Out:
# '[Diet Coke]'

# %%
#Step 12. How many items were orderd in total?
chipo.quantity.sum()
# Out:
# 4972

# %%
#Step 13.
# Turn the item price into a float
#Check the item price type
chipo.dtypes.item_price
# Out:
# dtype('O')

# %%
# Create a lambda function and change the type of item price
chipo.item_price = chipo.item_price.apply(lambda x: float(x[1:]))

# %%
# Check the item price type
chipo.item_price.dtypes
# Out:
# dtype('float64')

# %%
# step 14. How much was the revenue for the period in the dataset? 
chipo['revenue'] = chipo['quantity']*chipo.item_price
t_revenue = chipo.revenue.sum()
t_revenue
# Out:
# 39237.02

# %%
#Step 15. How many orders were made in the period?
t_orders = chipo.order_id.nunique()
t_orders
# Out:
# 1834

# %%
#Step 16. What is the average revenue amount per order?
chipo.groupby(by=['order_id']).sum().mean()['revenue']
# Out:
# C:\Users\samar\AppData\Local\Temp\ipykernel_8252\2623316158.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   chipo.groupby(by=['order_id']).sum().mean()['revenue']
# 21.39423118865867

# %%
# Step 17. How many different items are sold?
chipo.item_name.nunique()
# Out:
# 50

# %% [markdown]
# **Question 6: Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!**

# %%
m_data = pd.read_csv('us-marriages-divorces-1867-2014.csv')

# %%
m_data.head(10)
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
# 5  1872   378000.0   12000.0    42066000                 9.0
# 6  1873   386000.0   13000.0    43225000                 8.9
# 7  1874   385000.0   14000.0    44429000                 8.7
# 8  1875   409000.0   14000.0    45492000                 9.0
# 9  1876   405000.0   15000.0    46459000                 8.7
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3
# 5                0.3
# 6                0.3
# 7                0.3
# 8                0.3
# 9                0.3

# %%
# import necessary libraries
import matplotlib.pyplot as plt

# %%
m_data.plot(x='Year',y=['Marriages_per_1000','Divorces_per_1000'])
plt.title("Marriages and Divorces per capital in u.s State between 1867 and 2011")
plt.xlabel('Year')
plt.ylabel('Marriages and Divorces per Capita')
plt.show()

# %% [markdown]
# **Question 7 Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!**

# %%
m_data[m_data['Year']==1900]
# Out:
#     Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 33  1900   709000.0   56000.0    76094000                 9.3
#
#     Divorces_per_1000
# 33                0.7

# %%
m_data[m_data['Year']==1950]
# Out:
#     Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 83  1950  1667000.0  385000.0   151684000                11.0
#
#     Divorces_per_1000
# 83                2.5

# %%
m_data[m_data['Year']==2000]
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 133  2000  2315000.0  944000.0   282398000                 8.2
#
#      Divorces_per_1000
# 133                3.3

# %%
Divorse=[56000,385000,944000]
Marriges=[709000,1667231,2315000]

width=0.30
fig=plt.subplots(figsize=(12,8))

Mars=np.arange(len(Divorse))
Divs=[x+width for x in Mars]

plt.bar(Mars,Marriges,color='g', width=width,label="Marriges")
plt.bar(Divs,Divorse,color='b', width=width, label="Divorses")

plt.xlabel("Year", fontweight="bold", fontsize=15)
plt.ylabel("Marriges/Divorses", fontweight="bold", fontsize=15)

plt.xticks([r+width for r in range(len(Divorse))],["1900","1950","2000"])
plt.legend()
plt.show()

# %% [markdown]
# **Question 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!**

# %%
df_actor = pd.read_csv('actor_kill_counts.csv')
sorted_data = df_actor.sort_values('Count', ascending=False)
sorted_data
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 7     Sylvester Stallone    267
# 4         Dolph Lundgren    239
# 8    Tomisaburo Wakayama    226
# 2         Clint Eastwood    207
# 6           Nicolas Cage    204
# 5                 Jet Li    201
# 3             Clive Owen    194
# 9          Wesley Snipes    193

# %%
plt.barh(width=sorted_data['Count'],y= sorted_data['Actor'], color='b')

ax = plt.subplot()

plt.xlabel('Actor')

plt.ylabel('Kill Count')

plt.title('Top 10 Deadliest Actors')

plt.show()

# %% [markdown]
# **Question 9
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.**

# %%
import matplotlib.pyplot as plt
import pandas as pd
R_emperors = pd.read_csv('roman-emperor-reigns.csv')
As_emperors = R_emperors[
R_emperors['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]
Number_As = len(As_emperors)
Emperor = As_emperors["Emperor"]
cause_of_death = As_emperors["Cause_of_Death"]
plt.pie(range(len(cause_of_death)), labels=Emperor,autopct='%1.1f%%', startangle=90, radius=0.08 * 100)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dfbc0c8730>,
# ...
#  [Text(5.388445916248355e-16, 8.8, 'Augustus'),
#   Text(-0.06355350556839466, 8.799770505639904, 'Tiberius'),
#   Text(-0.25418087519481225, 8.796328329631928, 'Caligula'),
#   Text(-0.5715838525916983, 8.781417419725386, 'Claudius'),
#   Text(-1.014603498093826, 8.741314531674043, 'Galba'),
#   Text(-1.5802330760233507, 8.656954627664499, 'Vitellius'),
#   Text(-2.2622567580796455, 8.504245666755105, 'Domitian'),
#   Text(-3.0495563976684283, 8.254708097651882, 'Commodus'),
#   Text(-3.924170701120674, 7.876603602344484, 'Pertinax'),
#   Text(-4.859253435988567, 7.336733336085844, 'Caracalla'),
#   Text(-5.817160387583082, 6.6030784506269695, 'Geta'),
#   Text(-6.747994822848904, 5.648412685950311, 'Elagabalus'),
#   Text(-7.589048035193822, 4.454924232747489, 'Severus Alexander'),
#   Text(-8.265666264955097, 3.0197286627084967, 'Maximinus I'),
#   Text(-8.694128733123023, 1.3609282023254161, 'Pupienus'),
# ...

# %% [markdown]
# **Question 10
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
df1=df1.rename(columns = {'Total Arcade Revenue (billions)':'Revenue','Computer Science Doctorates Awarded (US)':'Awarded'})
groups = df1.groupby('Year')
for Name, Group in groups:
    plt.plot(Group.Revenue, Group.Awarded, marker='o', linestyle='', markersize=12, label=Name)
plt.legend()
plt.xlabel("REVENUE")
plt.ylabel("AWARDS")
plt.title('RELATIONSHIP BETWEEN REVENUE AND AWARDS')
plt.show()

# %% [markdown]
# #Reference for Problem Set 3
#
# https://pandas.pydata.org/docs/user_guide/index.html
